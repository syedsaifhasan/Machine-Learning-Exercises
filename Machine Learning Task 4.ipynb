# %%
from libsvm.svmutil import *

# %%
y, x = svm_read_problem('/home/syedsaifhasan/Course/Machine Learning/Seminar/heart_scale')
m = svm_train(y[:200], x[:200], '-c 4')
x
# Out:
# [{1: 0.708333,
#   2: 1.0,
#   3: 1.0,
#   4: -0.320755,
#   5: -0.105023,
#   6: -1.0,
#   7: 1.0,
#   8: -0.419847,
#   9: -1.0,
#   10: -0.225806,
#   12: 1.0,
#   13: -1.0},
#  {1: 0.583333,
#   2: -1.0,
#   3: 0.333333,
#   4: -0.603774,
#   5: 1.0,
#   6: -1.0,
#   7: 1.0,
#   8: 0.358779,
#   9: -1.0,
#   10: -0.483871,
#   12: -1.0,
#   13: 1.0},
#  {1: 0.166667,
#   2: 1.0,
#   3: -0.333333,
#   4: -0.433962,
#   5: -0.383562,
#   6: -1.0,
#   7: -1.0,
#   8: 0.0687023,
#   9: -1.0,
#   10: -0.903226,
#   11: -1.0,
#   12: -1.0,
#   13: 1.0},
#  {1: 0.458333,
#   2: 1.0,
#   3: 1.0,
#   4: -0.358491,
#   5: -0.374429,
#   6: -1.0,
#   7: -1.0,
#   8: -0.480916,
#   9: 1.0,
#   10: -0.935484,
#   12: -0.333333,
#   13: 1.0},
#  {1: 0.875,
#   2: -1.0,
#   3: -0.333333,
#   4: -0.509434,
#   5: -0.347032,
#   6: -1.0,
#   7: 1.0,
#   8: -0.236641,
#   9: 1.0,
#   10: -0.935484,
#   11: -1.0,
#   12: -0.333333,
#   13: -1.0},
#  {1: 0.5,
#   2: 1.0,
#   3: 1.0,
# ...

# %%
p_label, p_acc, p_val = svm_predict(y[200:], x[200:], m)
# Out:
# Accuracy = 84.2857% (59/70) (classification)
